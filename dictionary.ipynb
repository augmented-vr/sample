# %% [markdown]
# <a href="https://colab.research.google.com/github/augmented-vr/sample/blob/master/dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#辞書の定義
fruits_price = {
    "apple": 100,
    "banana": 150,
    "orange": 200
}

#辞書の中身を表示
print(fruits_price)
# Out:
# {'apple': 100, 'banana': 150, 'orange': 200}

# %%
#辞書の定義
fruits_price = {
    "apple": 100,
    "banana": 150,
    "orange": 200
}

#"apple"というキーに対応する値を取り出す
print(fruits_price["apple"])

#"orange"というキーに対応する値を取り出す
print(fruits_price["orange"])
# Out:
# 100
# 200

# %%
#辞書の定義
fruits_price = {
    "apple": 100,
    "banana": 150,
    "orange": 200
}

print(fruits_price)

#新しい商品"grape"とその値段を追加
fruits_price["grape"] = 300

print(fruits_price)
# Out:
# {'apple': 100, 'banana': 150, 'orange': 200}
# {'apple': 100, 'banana': 150, 'orange': 200, 'grape': 300}

# %%
#辞書の定義
fruits_price = {
    "apple": 100,
    "banana": 150,
    "orange": 200
}

print(fruits_price)

#"banana"の値段を変更
fruits_price["banana"] = 100

print(fruits_price)
# Out:
# {'apple': 100, 'banana': 150, 'orange': 200}
# {'apple': 100, 'banana': 100, 'orange': 200}
