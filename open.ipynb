# %% [markdown]
# <a href="https://colab.research.google.com/github/augmented-vr/sample/blob/master/open.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Googleドライブをcolabに接続(マウント)するための機能を入れる
from google.colab import drive

# 自分のGoogleドライブを /content/drive という場所にマウントする
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Googleドライブの「マイドライブ」の中に「memo.txt」を作るパスを指定
file_path = "/content/drive/MyDrive/memo.txt"

# ファイルを書き込みモード("w")で開く
with open(file_path, "w") as file:
  # ファイルに文字を書き込む(\n は改行の記号)
  file.write("Googleドライブへの保存テストです。\n")
  file.write("Googleドライブに保存しました!")

print("ファイルへの書き込みが終わりました。")
# Out:
# ファイルへの書き込みが終わりました。

# %%
# 読み込むファイルのパスを指定
file_path = "/content/drive/MyDrive/memo.txt"

# ファイルを読み込みモード("r")で開く
with open(file_path, "r") as file:
  # ファイルの中身をすべて読みこんで変数に入れる
  content = file.read()

# 読み込んだ内容を表示する
print("読み込んだテキスト: ")
print(content)
# Out:
# 読み込んだテキスト:
# Googleドライブへの保存テストです。
# Googleドライブに保存しました!

# %%
# 果物のリストを変数として定義する
favorite_fruits = ["もも", "なし", "かき"]

# 新しい保存先のパスを指定
list_file_path = "/content/drive/MyDrive/fruits.txt"

# ファイルを書き込みモード("w")で開く
with open(list_file_path, "w") as file:
  # for文を使って、リストの中身を順番に書き込む
  for fruit in favorite_fruits:
    file.write(fruit + "\n")

print("リストのデータをファイルに保存しました!")
# Out:
# リストのデータをファイルに保存しました!

# %%
# 読み込むファイルのパスを指定
list_file_path = "/content/drive/MyDrive/fruits.txt"

# ファイルを読み込みモード("r")で開く
with open(list_file_path, "r") as file:
  # ファイルの中身を全て読み込む
  saved_fruits = file.read()

# 読み込んだ内容を表示する
print("好きな果物: ")
print(saved_fruits)
# Out:
# 好きな果物:
# もも
# なし
# かき
