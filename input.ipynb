# %% [markdown]
# <a href="https://colab.research.google.com/github/augmented-vr/sample/blob/master/input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ユーザーに名前の入力を求める
name = input("あなたの名前は?:")

#入力された名前を使って挨拶する
print(f"こんにちは、{name}さん!")
# Out:
# あなたの名前は?:佐藤
# こんにちは、佐藤さん!

# %%
# 好きな数字を入力してもらう
number = input("好きな数字を入力してください:")

#入力された数字に10を足そうとする(エラーになります)
print(number + 10)
# Out:
# 好きな数字を入力してください:10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4034037714.py in <cell line: 0>()
#       3
#       4 #入力された数字に10を足そうとする(エラーになります)
# ----> 5 print(number + 10)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# 好きな数字を入力してもらう
number_str = input("好きな数字を入力してください:")

# 文字列を整数(int)に変換する
number = int(number_str)

# 10を足した結果を表示する
print(number + 10)
# Out:
# 好きな数字を入力してください:5
# 15
