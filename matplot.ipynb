# %% [markdown]
# <a href="https://colab.research.google.com/github/augmented-vr/sample/blob/master/matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# matplotlibライブラリをpltという名前で読み込む
import matplotlib.pyplot as plt

# X軸(横軸)とY軸(縦軸)のデータを用意する
x_data = [1, 2, 3, 4, 5]
y_data = [10, 20, 15, 30, 5]

# 折れ線グラフを描画する
plt.plot(x_data, y_data)

# グラフを画面に表示する
plt.show()

# %%
import matplotlib.pyplot as plt

# X軸の項目(カテゴリ)と、Y軸のデータ(数値)を用意する
categories = ["A", "B", "C", "D", "E"]
value = [15, 30, 15, 45, 20]

# 棒グラフを描画する
plt.bar(categories, value)

# グラフを画面に表示する
plt.show()

# %%
import matplotlib.pyplot as plt

# 円グラフの各項目の名前と、それぞれの割合(数値)を用意する
labels = ["Apple", "Banana", "Cherry", "Orange"]
sizes = [40, 30, 20, 10]

# 円グラフを描画する
plt.pie(sizes, labels = labels)

# グラフを画面に表示する
plt.show()

# %%
import matplotlib.pyplot as plt

# X軸とY軸のデータを用意する
x_points = [10, 20, 30, 40, 50, 60]
y_points = [10, 20, 15, 30, 5, 60]

# 散布図を描画する
plt.scatter(x_points, y_points)

# グラフを画面に表示する
plt.show()

# %% [markdown]
# Colabでmatplotlibで日本語を使いたい場合、`japanize-matplotlib`という日本語化専用の拡張ライブラリを使う必要がある。 <br>
# 使うにはコードセルで以下のコマンドを実行してインストールする(先頭の`!`を忘れないようにする)。 <br>
# `! pip install japanize-matplotlib`

# %%
# !pip install japanize-matplotlib

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib # これを追加する

# 以降はグラフに日本語が使えます
x_data = ["一", "二", "三"]
y_data = [10, 20, 30]

plt.bar(x_data, y_data)
plt.title("日本語を使用したグラフ")
plt.xlabel("横軸")
plt.ylabel("縦軸")

plt.show()
