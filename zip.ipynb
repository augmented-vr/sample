# %% [markdown]
# <a href="https://colab.research.google.com/github/augmented-vr/sample/blob/master/zip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 名前のリストと点数のリストを用意する
names = ["Alex", "Bob", "Corrin"]
scores = [90, 80, 70]

# zip関数で2つのリストの要素を同時に取得する
for name, score in zip(names, scores):
  print(f"{name}さんの点数は{score}点です。")
# Out:
# Alexさんの点数は90点です。
# Bobさんの点数は80点です。
# Corrinさんの点数は70点です。

# %%
# 長さの違う3つのリストを用意する
names = ["Alex", "Bob", "Corrin", "David", "Eve"] # 5
ages = [20, 40, 30] # 3
cities = ["Hokkaido", "Tokyo", "Kyoto", "Okinawa"] # 4

# 3つのリストをzip関数でまとめる
for name, age, city in zip(names, ages, cities):
  print(f"{name}さんは{age}歳で、{city}出身です。")
# Out:
# Alexさんは20歳で、Hokkaido出身です。
# Bobさんは40歳で、Tokyo出身です。
# Corrinさんは30歳で、Kyoto出身です。

# %%
# 文字列とリストを用意する
chars = "ABC"
numbers = [1, 2, 3]

# 文字列とリストをzip関数でまとめる
for char, num in zip(chars, numbers):
  print(f"文字は「{char}」、数字は「{num}」です。")
# Out:
# 文字は「A」、数字は「1」です。
# 文字は「B」、数字は「2」です。
# 文字は「C」、数字は「3」です。
